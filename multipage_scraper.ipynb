# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
def get(url):
    try:
        page = requests.get(url)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, 'lxml')
            return soup
        else:
            print('failed')
    except Exception as e:
        print(e)

# %%
def collect(soup,container):
    if soup:
        names = soup.find_all('div',attrs={'class':'_3wU53n'})
        prices = soup.find_all('div',attrs={'class':'_1vC4OE _2rQ-NK'})
        ratings= soup.find_all('span',attrs={'class':'_38sUEc'})
        try:
            url = soup.find_all('a',attrs={'class':'_3fVaIS'})[1]
        except:
            url = soup.find('a',attrs={'class':'_3fVaIS'})
        for nm,pr,rt in zip(names,prices,ratings):
            item = {'product':nm.text,
                    'price':pr.text,
                    'ratings':rt.text}
            container.append(item)
        if url:
            url = url.attrs.get('href')
            curl = "https://www.flipkart.com"+url
            print('next page link ==>',curl)
            return curl,container
        else:
            print('no next url found')
            return None,container

# %%
def save(filename,datalist):
    data= pd.DataFrame(datalist)
    data.to_csv(filename)
    print('saved to',filename)
    return data

# %%
container = []
url = "https://www.flipkart.com/search?q=mobiles"
while True:
    soup = get(url)
    newurl,container = collect(soup,container)
    if not newurl:
        print('the end')
        break
    else:
        url = newurl
save(filename='flipkart.csv',datalist=container)
# Out:
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=2
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=3
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=4
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=5
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=6
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=7
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=8
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=9
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=10
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=11
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=12
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=13
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=14
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=15
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=16
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=17
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=18
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=19
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=20
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=21
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=22
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=23
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=24
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=25
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=26
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=27
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=28
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=29
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=30
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=31
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=32
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=33
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=34
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=35
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=36
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=37
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=38
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=39
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=40
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=41
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=42
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=43
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=44
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=45
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=46
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=47
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=48
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=49
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=50
# next page link ==> https://www.flipkart.com/search?q=mobiles&page=51
# no next url found
# the end
# saved to flipkart.csv
#                                    product    price  \
# 0     Redmi Note 7S (Sapphire Blue, 64 GB)   ₹9,999
# 1             Redmi 8A (Ocean Blue, 32 GB)   ₹6,499
# 2        Redmi Note 7S (Onyx Black, 32 GB)   ₹8,999
# 3                             Niamia Cad V     ₹799
# 4         Realme 5 (Crystal Purple, 32 GB)   ₹8,999
# ...                                    ...      ...
# 1161                          Niamia Cad 4     ₹743
# 1162                              Zen X45+   ₹1,099
# 1163                        Jivi X606 Plus     ₹925
# 1164               Vivo Y83 (Black, 32 GB)  ₹15,990
# 1165               Honor 7C (Black, 32 GB)  ₹12,999
#
#                                 ratings
# 0     2,35,010 Ratings & 19,052 Reviews
# 1        19,185 Ratings & 1,558 Reviews
# 2     2,15,795 Ratings & 20,152 Reviews
# 3              162 Ratings & 15 Reviews
# 4        83,987 Ratings & 7,595 Reviews
# ...                                 ...
# 1161            37 Ratings & 11 Reviews
# 1162              3 Ratings & 0 Reviews
# 1163     10,694 Ratings & 1,226 Reviews
# 1164           792 Ratings & 75 Reviews
# 1165            100 Ratings & 5 Reviews
#
# [1166 rows x 3 columns]
